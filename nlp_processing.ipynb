# %% [markdown]
# # NLP Processing of Avalanche Forecasts

# %%
import pandas as pd

# %%
data = pd.read_csv('output_data/Snoqualmie_Pass_Current_Season_reports_data.csv')
data
# Out:
#               0                1             2                 3  \
# 0    2023-04-15  Snoqualmie Pass      MODERATE      2 - MODERATE
# 1    2023-04-14  Snoqualmie Pass           LOW           1 - LOW
# 2    2023-04-13  Snoqualmie Pass      MODERATE      2 - MODERATE
# 3    2023-04-12  Snoqualmie Pass      MODERATE      2 - MODERATE
# 4    2023-04-11  Snoqualmie Pass      MODERATE      2 - MODERATE
# ..          ...              ...           ...               ...
# 139  2022-11-29  Snoqualmie Pass  CONSIDERABLE  3 - CONSIDERABLE
# 140  2022-11-28  Snoqualmie Pass      MODERATE      2 - MODERATE
# 141  2022-11-27  Snoqualmie Pass      MODERATE      2 - MODERATE
# 142  2022-11-26  Snoqualmie Pass  CONSIDERABLE  3 - CONSIDERABLE
# 143  2022-11-25  Snoqualmie Pass      MODERATE      2 - MODERATE
#
#                     4             5  \
# 0             1 - LOW       1 - LOW
# 1             1 - LOW       1 - LOW
# 2        2 - MODERATE       1 - LOW
# ...

# %%
text = """Wind Slab
PROBLEM TYPE
N
E
S
W
NW
NE
SE
SW
Above Treeline
Near Treeline
Below Treeline
ASPECT/ELEVATION
Unlikely
Possible
Likely
Very Likely
Almost Certain
LIKELIHOOD
Small (D1)
Large (D2)
Very Large (D3)
Historic (D4-5)
SIZE
(4/11/2023)"""

# %%
import re
clean_text = re.sub(r'PROBLEM TYPE.*?SIZE', '', text, flags=re.DOTALL)
